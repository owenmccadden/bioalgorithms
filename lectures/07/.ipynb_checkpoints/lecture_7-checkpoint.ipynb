# %% [markdown]
# ## Generating all unique k-mers of hamming distance 1 from a given motif

# %%
kmer = "tagatccgaa"

hamming_dist = [kmer[:i]+alt+kmer[i+1:] for i, base in enumerate(kmer) for alt in "acgt" if alt != base]
print(hamming_dist, len(hamming_dist))
# Out:
# ['aagatccgaa', 'cagatccgaa', 'gagatccgaa', 'tcgatccgaa', 'tggatccgaa', 'ttgatccgaa', 'taaatccgaa', 'tacatccgaa', 'tatatccgaa', 'tagctccgaa', 'taggtccgaa', 'tagttccgaa', 'tagaaccgaa', 'tagacccgaa', 'tagagccgaa', 'tagatacgaa', 'tagatgcgaa', 'tagattcgaa', 'tagatcagaa', 'tagatcggaa', 'tagatctgaa', 'tagatccaaa', 'tagatcccaa', 'tagatcctaa', 'tagatccgca', 'tagatccgga', 'tagatccgta', 'tagatccgac', 'tagatccgag', 'tagatccgat'] 30
